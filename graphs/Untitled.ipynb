# %%
import boto3
import pandas as pd

# %%
import os
os.environ["AWS_DEFAULT_REGION"] = 'us-east-2'
os.environ["AWS_ACCESS_KEY_ID"] = 'AKIA3YG72WSKAY3DQARO'
os.environ["AWS_SECRET_ACCESS_KEY"] = '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'

# %%
for obj in s3.Bucket('mlops-storage1').objects.all():
    print(obj.bucket_name)
# Out:
# mlops-storage1
# mlops-storage1
# mlops-storage1
# mlops-storage1
# mlops-storage1
# mlops-storage1
# mlops-storage1
# mlops-storage1
# mlops-storage1
# mlops-storage1
# mlops-storage1
# mlops-storage1
# mlops-storage1
# mlops-storage1
# mlops-storage1
# mlops-storage1
# mlops-storage1
# mlops-storage1
# mlops-storage1
# mlops-storage1
# mlops-storage1
# mlops-storage1
# mlops-storage1
# mlops-storage1
# mlops-storage1
# mlops-storage1
# mlops-storage1
# mlops-storage1
# mlops-storage1

# %%
obj= s3.Bucket('mlops-storage1').Object('hari/bank.csv').get()
foo = pd.read_csv(obj['Body'])

# %%
foo
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %%
for bucket in s3.buckets.all():
    print(bucket.name)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Input In [18], in <cell line: 1>()
# ----> 1 for bucket in s3.buckets.all():
#       2     print(bucket.name)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\boto3\resources\collection.py:81, in ResourceCollection.__iter__(self)
#      78 limit = self._params.get('limit', None)
#      80 count = 0
# ---> 81 for page in self.pages():
#      82     for item in page:
#      83         yield item
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\boto3\resources\collection.py:166, in ResourceCollection.pages(self)
#     159 else:
#     160     logger.debug(
#     161         'Calling %s:%s with %r',
#     162         self._parent.meta.service_name,
#     163         self._py_operation_name,
#     164         params,
#     165     )
# ...
